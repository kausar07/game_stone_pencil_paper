# %%
from IPython.display import display, Image
import sys
path0 = "Downloads/tai.jpg"
path1 = "Downloads/cup.jpeg"
path2 = "Downloads/lost.jpeg"
path3 = "Downloads/namaste.png"
path4 = "Downloads/stone.jpg"
import random
print("\n\n!!!!!*******    WELLCOME TO STONE,PENCIL,PAPER GAME     *********!!!!!!\n\n")
img = Image(path4)
display(img)
print("1.Stone\n2.Pencil\n3.Paper\n")
comp=0
user=0
j=0
for i in range(j,5):
    n=random.choice([1,2,3])
    m=int(input())
    if m <=3:
        if n==m:
            print("Machine-->",n,"\t\t","User-->",m)
        elif n==1 and m==2:
            print("Machine-->",n,"\t\t","User-->",m)
            comp=comp+1
        elif n==1 and m==3:
            print("Machine-->",n,"\t\t","User-->",m)
            user +=1
        elif n==2 and m==1:
            print("Machine-->",n,"\t\t","User-->",m)
            user +=1
        elif n==2 and m==3:
            print("Machine-->",n,"\t\t","User-->",m)
            comp +=1
        elif n==3 and m==1:
            print("Machine-->",n,"\t\t","User-->",m)
            comp +=1
        elif n==3 and m==2:
            print("Machine-->",n,"\t\t","User-->",m)
            user +=1
    else:
        print("\n\nPlease enter between 1 and 3!!!!!!!!!!!!!")
        print("\n Now  RESTART the program\nTHANKYOU\n\n")
        img = Image(path3)
        display(img)
        sys.exit(0)
if user == comp:
    print("\n\n\n***************   MATCH TIED  ***************")
    img = Image(path0)
    display(img)
elif user >comp:
    print("\n\n\n*******  YOU WON *********")
    img = Image(path1)
    display(img)
else:
    print("\n\n\n******** YOU LOST!!!!!!!!!\t TRY NEXT TIME  *******")
    img = Image(path2)
    display(img)
# Out:
# !!!!!*******    WELLCOME TO STONE,PENCIL,PAPER GAME     *********!!!!!!
# 1.Stone
# 2.Pencil
# 3.Paper
